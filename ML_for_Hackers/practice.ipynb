# %%
data.file<-file.path('../../ML_for_Hackers/02-Exploration//data/01_heights_weights_genders.csv')

# %%
data.file
# Out:
# [1] "../../ML_for_Hackers/02-Exploration//data/01_heights_weights_genders.csv"

# %%
h_w<-read.csv(data.file, header=TRUE,sep=',')

# %%
head(h_w)
# Out:
#   Gender Height   Weight
# 1 Male   73.84702 241.8936
# 2 Male   68.78190 162.3105
# 3 Male   74.11011 212.7409
# 4 Male   71.73098 220.0425
# 5 Male   69.88180 206.3498
# 6 Male   67.25302 152.2122

# %%
h<-with(h_w,Height)

# %%
head(h)
# Out:
# [1] 73.84702 68.78190 74.11011 71.73098 69.88180 67.25302

# %%
summary(h)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#   54.26   63.51   66.32   66.37   69.17   79.00

# %%
library(ggplot2)

# %%
ggplot(h_w, aes(x=Height))+geom_histogram(binwidth =1)
# Out:
# plot without title

# %%
ggplot(h_w,aes(x=Height, fill=Gender))+geom_density()
# Out:
# plot without title

# %%
ggplot(h_w,aes(x=Height,y=Weight))+geom_point()+geom_smooth(method='glm')
# Out:
# plot without title

# %%
install.packages('slam')
# Out:
# Installing package into '/home/vmuser/rlib'
# (as 'lib' is unspecified)
# Warning message:
# "package 'slam' is not available (for R version 3.2.3)"
